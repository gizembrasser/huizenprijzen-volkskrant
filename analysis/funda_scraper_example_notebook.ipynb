# %%
# !pip install funda-scraper
# Out:
# Collecting funda-scraper
#   Downloading funda_scraper-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: beautifulsoup4>=4.8 in /usr/local/lib/python3.10/dist-packages (from funda-scraper) (4.12.3)
# Requirement already satisfied: requests>=2 in /usr/local/lib/python3.10/dist-packages (from funda-scraper) (2.32.3)
# Collecting diot>=0.1.5 (from funda-scraper)
#   Downloading diot-0.2.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: PyYAML>=5.0 in /usr/local/lib/python3.10/dist-packages (from funda-scraper) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.0 in /usr/local/lib/python3.10/dist-packages (from funda-scraper) (4.66.5)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from funda-scraper) (2.2.2)
# Requirement already satisfied: lxml>=4 in /usr/local/lib/python3.10/dist-packages (from funda-scraper) (4.9.4)
# Collecting urllib3==1.26 (from funda-scraper)
#   Downloading urllib3-1.26.0-py2.py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.8->funda-scraper) (2.6)
# Collecting inflection<0.6,>=0.5 (from diot>=0.1.5->funda-scraper)
#   Downloading inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->funda-scraper) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->funda-scraper) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->funda-scraper) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->funda-scraper) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2->funda-scraper) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2->funda-scraper) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2->funda-scraper) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2->funda-scraper) (1.16.0)
# Downloading funda_scraper-1.2.1-py3-none-any.whl (24 kB)
# Downloading urllib3-1.26.0-py2.py3-none-any.whl (136 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.7/136.7 kB 3.8 MB/s eta 0:00:00
# Downloading diot-0.2.3-py3-none-any.whl (11 kB)
# Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Installing collected packages: urllib3, inflection, diot, funda-scraper
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentry-sdk 2.16.0 requires urllib3>=1.26.11, but you have urllib3 1.26.0 which is incompatible.
# Successfully installed diot-0.2.3 funda-scraper-1.2.1 inflection-0.5.1 urllib3-1.26.0

# %%
from funda_scraper import FundaScraper

scraper = FundaScraper(area="amsterdam", want_to="rent", find_past=False, n_pages=1)
scraper
# Out:
# FundaScraper(area=amsterdam, want_to=rent, n_pages=1, page_start=1, find_past=False, min_price=None, max_price=None, days_since=None, min_floor_area=None, max_floor_area=None, find_past=False)min_price=None)max_price=None)days_since=None)sort=None)

# %%
df = scraper.run()
# Out:
# *** Phase 1: Fetch all the available links from all pages ***
# INFO:funda_scraper:*** Phase 1: Fetch all the available links from all pages ***
# *** Main URL: https://www.funda.nl/en/zoeken/huur?selected_area=%5B%22amsterdam%22%5D ***
# INFO:funda_scraper:*** Main URL: https://www.funda.nl/en/zoeken/huur?selected_area=%5B%22amsterdam%22%5D ***
# 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# *** Got all the urls. 15 houses found from 1 to 1 ***
# INFO:funda_scraper:*** Got all the urls. 15 houses found from 1 to 1 ***
# *** Phase 2: Start scraping from individual links ***
# INFO:funda_scraper:*** Phase 2: Start scraping from individual links ***
#   0%|          | 0/15 [00:00<?, ?it/s]
# *** All scraping done: 15 results ***
# INFO:funda_scraper:*** All scraping done: 15 results ***
# *** Cleaning data ***
# INFO:funda_scraper:*** Cleaning data ***
# *** Done! ***
# INFO:funda_scraper:*** Done! ***

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [url, house_id, city, house_type, building_type, price, price_m2, room, bedroom, bathroom, living_area, energy_label, zip, address, year_built, house_age, descrip, photo]
# Index: []

# %%
scraper.save_csv(df)
# Out:
# 2022-09-17 11:41:23,911 - INFO - *** File saved: ./data/houseprice_20220917_amsterdam_renting_15.csv. *** (scrape.py:217)
# INFO:funda_scraper:*** File saved: ./data/houseprice_20220917_amsterdam_renting_15.csv. ***

# %%
scraper.clean_df.head(1)
# Out:
# Empty DataFrame
# Columns: [url, house_id, city, house_type, building_type, price, price_m2, room, bedroom, bathroom, living_area, energy_label, zip, address, year_built, house_age, descrip, photo]
# Index: []

# %%
scraper.raw_df.head(1)
# Out:
#                                                  url price address descrip  \
# 0  https://www.funda.nl/koop/amsterdam/appartemen...    na      na      na
#
#   listed_since zip_code size year living_area kind_of_house  ... ownership  \
# 0           na       na   na   na          na            na  ...        na
#
#   exteriors parking neighborhood_name               date_list last_ask_price  \
# 0        na      na                na  € 975.000 kosten koper             na
#
#   last_ask_price_m2 photo       city            log_id
# 0                na        amsterdam  202410-2110-0901
#
# [1 rows x 27 columns]

# %%
scraper.links
# Out:
# ['https://www.funda.nl/koop/amsterdam/appartement-43611489-leimuidenstraat-12-2/?old_ldp=true',
#  'https://www.funda.nl/koop/amsterdam/appartement-43635957-ndsm-straat-139/?old_ldp=true',
#  'https://www.funda.nl/huur/amsterdam/appartement-43766576-tweede-kostverlorenkade-28-3/?old_ldp=true',
#  'https://www.funda.nl/huur/amsterdam/huis-43648671-durgerdammerdijk-101/?old_ldp=true',
#  'https://www.funda.nl/huur/amsterdam/appartement-43779040-mary-van-der-sluisstraat-512/?old_ldp=true',
#  'https://www.funda.nl/huur/amsterdam/appartement-43760446-haparandaweg-660/?old_ldp=true',
#  'https://www.funda.nl/huur/amsterdam/appartement-43684936-rosy-wertheimstraat-75/?old_ldp=true',
#  'https://www.funda.nl/huur/amsterdam/appartement-43761162-dever-32/?old_ldp=true',
#  'https://www.funda.nl/huur/amsterdam/appartement-43630661-vossiusstraat-44-h/?old_ldp=true',
#  'https://www.funda.nl/huur/amsterdam/huis-43602802-cannenburg-15/?old_ldp=true',
#  'https://www.funda.nl/huur/amsterdam/appartement-43620913-hoogte-kadijk-414/?old_ldp=true',
#  'https://www.funda.nl/huur/amsterdam/appartement-43681551-gerard-schaepstraat-9-4/?old_ldp=true',
#  'https://www.funda.nl/huur/amsterdam/appartement-43692652-gietersstraat-33/?old_ldp=true',
#  'https://www.funda.nl/koop/amsterdam/appartement-43617116-johm-coenenstraat-60/?old_ldp=true',
#  'https://www.funda.nl/koop/amsterdam/appartement-43658648-ton-de-leeuwstraat-56/?old_ldp=true']
